# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

print("DONE")
# Out:
# DONE

# %%
#visa = pd.read_csv('vi_005.csv')

visa = pd.read_excel('Libro2.xlsx')
visa
# Out:
#            Geographical region            Country of nationality     2005  \
# 0                       *Total                            *Total  2065424
# 1                 Africa North               *Total Africa North    79138
# 2           Africa Sub-Saharan         *Total Africa Sub-Saharan   312395
# 3                America North              *Total America North    42403
# 4    America Central and South  *Total America Central and South    59612
# ..                         ...                               ...      ...
# 259                    Oceania                 Wallis and Futuna        0
# 260               Africa North                    Western Sahara        0
# 261                Middle East                             Yemen     3611
# 262         Africa Sub-Saharan                            Zambia     5404
# 263         Africa Sub-Saharan                          Zimbabwe    18915
#
#         2006     2007     2008     2009     2010     2011     2012     2013  \
# ...

# %%
visa.head()
# Out:
#          Geographical region            Country of nationality     2005  \
# 0                     *Total                            *Total  2065424
# 1               Africa North               *Total Africa North    79138
# 2         Africa Sub-Saharan         *Total Africa Sub-Saharan   312395
# 3              America North              *Total America North    42403
# 4  America Central and South  *Total America Central and South    59612
#
#       2006     2007     2008     2009     2010     2011     2012     2013  \
# 0  2228261  2062634  1954605  1995353  2144621  2275417  2228762  2496488
# 1    87720    78194    79734    80331    87854    73838    81000    94654
# 2   275701   257988   240565   316245   332960   340493   322737   316422
# 3    44124    44730    47159    46587    49713    47355    45250    49181
# 4    60907    62848    59685    56535    56986    53613    54492    58077
#
#       2014     2015     2016     2017
# 0  2448563  2468347  2478973  2710350
# ...

# %%
#visa.info()

# %%
list(visa)
# Out:
# ['Geographical region',
#  'Country of nationality',
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017]

# %%
visa_convert = visa.iloc[:,2:]

# %%
visa_convert
# Out:
#         2005     2006     2007     2008     2009     2010     2011     2012  \
# 0    2065424  2228261  2062634  1954605  1995353  2144621  2275417  2228762
# 1      79138    87720    78194    79734    80331    87854    73838    81000
# 2     312395   275701   257988   240565   316245   332960   340493   322737
# 3      42403    44124    44730    47159    46587    49713    47355    45250
# 4      59612    60907    62848    59685    56535    56986    53613    54492
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 259        0        0        0        0        0        0        0        0
# 260        0        0        0        0        0        0        0        0
# 261     3611     3903     3439     2912     2468     2462     1983     2106
# 262     5404     5469     5329     4606     3825     3764     3723     3877
# 263    18915    14847    12329     9693     7137     8015     8064     7390
#
#         2013     2014     2015     2016     2017
# ...

# %%
#visa_converted[visa_converted.loc[:] == 'z'].count()

visa_convert[visa_convert.loc[:] == 'z'].count()
# Out:
# 2005    8
# 2006    8
# 2007    5
# 2008    5
# 2009    5
# 2010    5
# 2011    2
# 2012    2
# 2013    2
# 2014    2
# 2015    2
# 2016    2
# 2017    2
# dtype: int64

# %%
years = list(visa_convert)

# %%
visa_convert[years] = visa_convert[years].replace("z","0")

#years = (visa_convert[years].replace("z","0"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
visa_convert[visa_convert.loc[:] == 'z'].count()
# Out:
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# dtype: int64

# %%
for i in years:
    visa_convert[i] = visa_convert[i].str.replace(",","").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-9009e1b8cef3> in <module>
#       1 for i in years:
# ----> 2     visa_convert[i] = visa_convert[i].str.replace(",","").astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
visa_convert.head()
# Out:
#       2005     2006     2007     2008     2009     2010     2011     2012  \
# 0  2065424  2228261  2062634  1954605  1995353  2144621  2275417  2228762
# 1    79138    87720    78194    79734    80331    87854    73838    81000
# 2   312395   275701   257988   240565   316245   332960   340493   322737
# 3    42403    44124    44730    47159    46587    49713    47355    45250
# 4    59612    60907    62848    59685    56535    56986    53613    54492
#
#       2013     2014     2015     2016     2017
# 0  2496488  2448563  2468347  2478973  2710350
# 1    94654    90545    83540    81839    80532
# 2   316422   298217   289329   236076   258073
# 3    49181    48595    48370    45438    46030
# 4    58077    69800    73813    66161    72351

# %%
visa_new = visa.drop(visa.iloc[:,2:], axis=1).join(visa_convert)

# %%
#visa_new.info()

# %%
visa_new_copy = visa_new.copy()
visa_new_copy.head(20)
# Out:
#           Geographical region            Country of nationality     2005  \
# 0                      *Total                            *Total  2065424
# 1                Africa North               *Total Africa North    79138
# 2          Africa Sub-Saharan         *Total Africa Sub-Saharan   312395
# 3               America North              *Total America North    42403
# 4   America Central and South  *Total America Central and South    59612
# 5                Asia Central               *Total Asia Central    18531
# 6                   Asia East                  *Total Asia East   195703
# 7                  Asia South                 *Total Asia South   594374
# 8             Asia South East            *Total Asia South East   121080
# 9                       EU 14                      *Total EU 14       47
# 10                       EU 2                       *Total EU 2    61675
# 11                       EU 8                       *Total EU 8       69
# ...

# %%
visa_new = visa_new.drop(visa_new.iloc[:17,:].index)

# %%
visa_new.head(20)
# Out:
#           Geographical region Country of nationality   2005   2006   2007  \
# 17               Asia Central            Afghanistan   3699   5448   6230
# 18               Europe Other                Albania  11562  10060   8633
# 19               Africa North                Algeria  10912  12481  12506
# 20                    Oceania         American Samoa      0      0      0
# 21               Europe Other                Andorra      3      7      7
# 22         Africa Sub-Saharan                 Angola   3862   3909   4165
# 23                      Other     Anguilla (British)      1      0      0
# 24  America Central and South    Antigua and Barbuda     37     45     39
# 25  America Central and South              Argentina    863    914    900
# 26               Europe Other                Armenia   1656   1726   1915
# 27  America Central and South                  Aruba      0      0      0
# 28                    Oceania              Australia  37375  36311  31464
# ...

# %%
visa_new = visa_new.reset_index()

# %%
visa_new = visa_new.drop('index',axis=1)

# %%
visa_new.head()
# Out:
#   Geographical region Country of nationality   2005   2006   2007   2008  \
# 0        Asia Central            Afghanistan   3699   5448   6230   4400
# 1        Europe Other                Albania  11562  10060   8633   6084
# 2        Africa North                Algeria  10912  12481  12506  13146
# 3             Oceania         American Samoa      0      0      0      0
# 4        Europe Other                Andorra      3      7      7      1
#
#     2009  2010   2011   2012   2013   2014   2015   2016   2017
# 0   4404  4150   4884   3390   2853   3106   2829   2474   2651
# 1   5589  5729   4494   4863   4400   4836   5871   6163   6593
# 2  11072  9545  11526  12026  15428  15079  16335  15285  15171
# 3      0     0      0      0      0      0      0      0      0
# 4      3     3      3      2      4      9      9      9     13

# %%
visa_new['Geographical region'].unique()
# Out:
# array(['Asia Central', 'Europe Other', 'Africa North', 'Oceania',
#        'Africa Sub-Saharan', 'Other', 'America Central and South',
#        'EU 14', 'Middle East', 'Asia South', 'Asia South East', 'EU 2',
#        'America North', 'Asia East', 'EU Other', 'EU 8'], dtype=object)

# %%
visa_grouped = visa_new.groupby(['Geographical region', 'Country of nationality'])

# %%
visa_grouped = visa_grouped.sum()

# %%
visa_grouped
# Out:
#                                                                2005   2006  \
# Geographical region Country of nationality
# Africa North        Algeria                                   10912  12481
#                     Egypt                                     24867  28885
#                     Libya                                     14808  16410
#                     Mauritania                                  302    339
#                     Morocco                                   14586  15173
# ...                                                             ...    ...
# Other               South Georgia and South Sandwich Islands      0      0
#                     St. Helena (British)                          0      0
#                     Stateless                                  1861   1730
#                     Turks and Caicos Islands (British)            0      1
#                     Virgin Islands (British)                      0      0
#
# ...

# %%
visa_grouped
# Out:
#                                                                2005   2006  \
# Geographical region Country of nationality
# Africa North        Algeria                                   10912  12481
#                     Egypt                                     24867  28885
#                     Libya                                     14808  16410
#                     Mauritania                                  302    339
#                     Morocco                                   14586  15173
# ...                                                             ...    ...
# Other               South Georgia and South Sandwich Islands      0      0
#                     St. Helena (British)                          0      0
#                     Stateless                                  1861   1730
#                     Turks and Caicos Islands (British)            0      1
#                     Virgin Islands (British)                      0      0
#
# ...
